# %%
import numpy as np
from numpy.linalg import det
import matplotlib.pyplot as plt
import sys
# %matplotlib inline

# %% [markdown]
# ## Useful functions

# %%
def I_XY(X,Y):
    
    dim_X = X.ndim
    dim_Y = Y.ndim
    
    cov = np.cov(X,Y)
    if (dim_X == 1):
        det_sigma_X = cov[0,0]
    elif (dim_X > 1):
        det_sigma_X = np.linalg.det(cov[:dim_X,:dim_X])
    if (dim_Y == 1):
        det_sigma_Y = cov[dim_X,dim_X]
    elif (dim_Y > 1):
        det_sigma_Y = np.linalg.det(cov[dim_X:,dim_X:])
        
    I = np.log2((det_sigma_X*det_sigma_Y)/np.linalg.det(cov))
    
    return I

def I_XYZ(X,Y,Z):
    
    dim_X = X.ndim
    dim_Y = Y.ndim
    dim_Z = Z.ndim
    
    cov = np.cov(np.vstack((X,Y,Z)))
    if (dim_X == 1):
        det_sigma_X = cov[0,0]
    elif (dim_X > 1):
        det_sigma_X = np.linalg.det(cov[:dim_X,:dim_X])
    det_sigma_YZ = np.linalg.det(cov[dim_X:,dim_X:])
        
    I = np.log2((det_sigma_X*det_sigma_YZ)/np.linalg.det(cov))
    
    return I

def PID(X,Y,Z):
    I_xy = I_XY(X,Y)
    I_xz = I_XY(X,Z)
    I_xyz = I_XYZ(X,Y,Z)
    
    R = min(I_xy,I_xz)
    
    if R == I_xy:
        Uy = 0
        Uz = I_xz - I_xy
        S = I_xyz - I_xz   
    else:
        Uz = 0
        Uy = I_xy - I_xz
        S = I_xyz - I_xy
    return Uy, Uz, S, R

# %%
time=np.linspace(0,10,1000)
data = np.zeros((2,len(time)))
A = np.random.rand(2,2)
A[1,0] = 0
A[1,1] = 0
S=np.array([[1,0],[0,1]])
for i in range(len(time)-1):
    data[:,i+1]=np.dot(A,data[:,i])+np.random.multivariate_normal(mean=[0,0],cov=S)

# %% [markdown]
# ## S  proporzionale all'identità (A(0,1)=0 ,   A(1,0)=0)

# %%
time=np.linspace(0,10,1000)
data = np.zeros((2,len(time)))
A = np.random.rand(2,2)
A[0,1] = 0
A[1,0] = 0
S=np.array([[1,0],[0,1]])
for i in range(len(time)-1):
    data[:,i+1]=np.dot(A,data[:,i])+np.random.multivariate_normal(mean=[0,0],cov=S)

# %%
plt.plot(time,data[0],label="x")
plt.plot(time,data[1],label="y")
plt.xlabel("t")
plt.legend()
plt.show()

# %%
# slice for PID

Y = data[0,:-1]
Z = data[1,:-1]
X = data[:,1:]

Uy, Uz, S, R = PID(X,Y,Z)
print("Uy:",Uy)
print("Uz:",Uz)
print("S:",S)
print("R",R)
# Out:
# Uy: 0
# Uz: 1.0844830052029089
# S: 4.47322861328927
# R 4.4725143313199185

# %% [markdown]
# ## S  proporzionale all'identità (A(0,1)=0)

# %%
time=np.linspace(0,10,1000)
data = np.zeros((2,len(time)))
A = np.random.rand(2,2)
A[0,1] = 0
S=np.array([[1,0],[0,1]])
for i in range(len(time)-1):
    data[:,i+1]=np.dot(A,data[:,i])+np.random.multivariate_normal(mean=[0,0],cov=S)

# %%
plt.plot(time,data[0],label="x")
plt.plot(time,data[1],label="y")
plt.xlabel("t")
plt.legend()
plt.show()

# %%
# slice for PID

Y = data[0,:-1]
Z = data[1,:-1]
X = data[:,1:]

Uy, Uz, S, R = PID(X,Y,Z)
print("Uy:",Uy)
print("Uz:",Uz)
print("S:",S)
print("R",R)
# Out:
# Uy: 5.472508694338144
# Uz: 0
# S: 1.176668663878365
# R 1.2626104784794019

# %% [markdown]
# ## S  proporzionale all'identità (A(1,0)=0)

# %%
time=np.linspace(0,10,1000)
data = np.zeros((2,len(time)))
A = np.random.rand(2,2)
A[1,0] = 0
S=np.array([[1,0],[0,1]])
for i in range(len(time)-1):
    data[:,i+1]=np.dot(A,data[:,i])+np.random.multivariate_normal(mean=[0,0],cov=S)

# %%
plt.plot(time,data[0],label="x")
plt.plot(time,data[1],label="y")
plt.xlabel("t")
plt.legend()
plt.show()

# %%
# slice for PID

Y = data[0,:-1]
Z = data[1,:-1]
X = data[:,1:]

Uy, Uz, S, R = PID(X,Y,Z)
print("Uy:",Uy)
print("Uz:",Uz)
print("S:",S)
print("R",R)
# Out:
# Uy: 0
# Uz: 1.058197328488112
# S: 0.2906389234048181
# R 0.2889151495358882

# %% [markdown]
# ## S  non diagonale (A(0,1)=0 ,   A(1,0)=0)

# %%
time=np.linspace(0,10,1000)
data = np.zeros((2,len(time)))
A = np.random.rand(2,2)
A[0,1] = 0
A[1,0] = 0
S=np.array([[1,0.5],[0.5,1]])
for i in range(len(time)-1):
    data[:,i+1]=np.dot(A,data[:,i])+np.random.multivariate_normal(mean=[0,0],cov=S)

# %%
plt.plot(time,data[0],label="x")
plt.plot(time,data[1],label="y")
plt.xlabel("t")
plt.legend()
plt.show()

# %%
# slice for PID

Y = data[0,:-1]
Z = data[1,:-1]
X = data[:,1:]

Uy, Uz, S, R = PID(X,Y,Z)
print("Uy:",Uy)
print("Uz:",Uz)
print("S:",S)
print("R",R)
# Out:
# Uy: 0
# Uz: 3.079880946727088
# S: 0.0072113900083126126
# R 0.07230765416806162
